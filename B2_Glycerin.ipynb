# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasBeu/B2-Brownian-motion/blob/main/B2_Glycerin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install panda
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7238 sha256=22054b7d7b527029b2a6ac5c86aef4421f12ecffa9f36fff4008a96efd17b53c
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# ...

# %%
import pandas as pd

# %%
A = pd.read_excel("Glycerin(1).xlsx")
T = A[A.columns[1]].values.tolist()
D = A[A.columns[3]].values.tolist()
V=A[A.columns[5]].values.tolist()
print(T,D,Eta)
# Out:
# [298.15, 301.15, 304.15, 307.15, 310.15, 313.15, 316.15, 319.15, 322.15] [0.594533, 0.6861, 0.996669, 1.222643, 1.4442543, 1.97542, 1.614682, 2.1090165, 2.481985] [1.46857727258943, 1.285385518821, 0.89366515595625, 0.73567976112441, 0.628877520419433, 0.464227564719289, 0.573382107905117, 0.443152114559143, 0.38009918451312]

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from scipy.optimize import curve_fit

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %%
plt.xlabel("T [K]")
plt.ylabel("D["u"\u03bcm^2/s]")
plt.title("Diffusion coefficient versus Temperature")
plt.suptitle("Glycerin")
plt.grid(which='both')
plt.plot(T,D,".y")

def func(x, a):
    return a*x
def fit(func, x, y):
    popt, pcov = curve_fit(func, x,y)
    return popt[0], pcov
x = np.linspace(T[0], T[8], num=50)
fit00 = fit(func, T, D)
plt.plot(x, func(x, fit00[0]), "-y")
print(fit00)
plt.savefig("Diffusion coefficient Glycerin versus Temperature")
# Out:
# (0.004747019468872441, array([[4.32180083e-07]]))

# %%
plt.xlabel("T [K]")
plt.ylabel("Viscosity[mPa*s]")
plt.title("Viscosity versus Temperature")
plt.suptitle("Glycerin")
plt.grid(which='both')
plt.plot(T,V,".k")
plt.plot(T,V,"-k",label="unknown")
Temperatur = [293.15,303.15,313.15,323.15]
Null = [1.005,0.8007,0.656,0.5495]
Zehn = [1.31,1.03,0.826,0.680]
Zwanzig = [1.76,1.35,1.07,0.879]
Dreißig = [2.5,1.87,1.46,1.16]
plt.plot(Temperatur,Null,"-b", label="0%")
plt.plot(Temperatur,Zehn,"-r",label="10%")
plt.plot(Temperatur,Zwanzig,"-g",label = "20%")
plt.plot(Temperatur,Dreißig,"y", label = "30%")
plt.legend(loc="upper right")

#def func(x, a, b,c):
   # return a*np.exp(-x*b)+c
#def fit(func, x, y):
   # popt, pcov = curve_fit(func, x, y)
   # return popt[0], popt[1],popt[2], pcov

#x = np.linspace(T[0],T[8], num=50)
#fit00 = fit(func, T, V)
#plt.plot(x, func(x, fit00[0], fit00[1],fit00[2]), "-k")
#print(fit00)
plt.savefig("Glycerin Viscosity versus Temperature")
